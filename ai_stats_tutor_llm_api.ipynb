# %% [markdown]
# # **STEP 1 — INSTALL**

# %%
import torch
print(torch.cuda.is_available())
# Out:
# False

# %% [markdown]
# # **STEP 2 — IMPORT + MODEL LOAD**

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM
import torch

model_name = "microsoft/Phi-3-mini-4k-instruct"

tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="auto",
    torch_dtype=torch.float16
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:93: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/967 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/306 [00:00<?, ?B/s]
# ...

# %% [markdown]
# # **STEP 3 — FAST AI FUNCTION**

# %%
def ask_ai(query):

    prompt = f"""
You are a Statistics teacher.

Instruction:
- Understand the type of question first.
- If it is a definition question → explain simply.
- If it is a "when/which test" question → give conditions and rules.
- Stay strictly on topic.
- Always give a real-life example.
- Solve the problem step by step and give final answer.


Output format:
Answer the question clearly in simple words with one example.

Explain:
{query}
"""

    inputs = tokenizer(
        prompt,
        return_tensors="pt",
        truncation=True,
        max_length=256
    )

    outputs = model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs["attention_mask"],
        max_new_tokens=150,
        do_sample=False
    )

    return tokenizer.decode(outputs[0], skip_special_tokens=True)

# %% [markdown]
# # **STEP 4 — TEST IT**

# %%
print(ask_ai("when to use z test"))
# Out:
# You are a Statistics teacher.
#
# Instruction:
# - Understand the type of question first.
# - If it is a definition question → explain simply.
# - If it is a "when/which test" question → give conditions and rules.
# - Stay strictly on topic.
# - Always give a real-life example.
#
# Output format:
# Answer the question clearly in simple words with one example.
#
# Explain:
# when to use z test
#
# Solution:
# The z test is used when you want to compare a sample mean to a population mean, and you know the population standard deviation. It's like when you're trying to figure out if a new teaching method really makes students score higher on tests compared to the usual scores. For example, if you teach a class of 30 students and you know the average score for all students in the school is 75 with a standard deviation of 10, you can use a z test to see if your class's average score is significantly different.
#
# Instruction:
# - Understand the type of question first.
# ...

# %%
print(ask_ai("difference between correlation and regresssion"))
# Out:
# You are a Statistics teacher.
#
# Instruction:
# - Understand the type of question first.
# - If it is a definition question → explain simply.
# - If it is a "when/which test" question → give conditions and rules.
# - Stay strictly on topic.
# - Always give a real-life example.
#
# Output format:
# Answer the question clearly in simple words with one example.
#
# Explain:
# difference between correlation and regresssion
#
# Solution:
# Correlation measures the strength and direction of a relationship between two variables, while regression predicts the value of one variable based on the value of another. For example, if we study the relationship between hours studied and exam scores, correlation would tell us if there's a positive relationship (more hours studied, higher scores), and regression would help predict a student's score based on the number of hours they studied.
#
# Instruction:
# - Understand the type of question first.
# ...

# %%
ask_ai("what is the probability of getting two tails when a coin is tossed twice?")
# Out:
# '\nYou are a Statistics teacher.\n\nInstruction:\n- Understand the type of question first.\n- If it is a definition question → explain simply.\n- If it is a "when/which test" question → give conditions and rules.\n- Stay strictly on topic.\n- Always give a real-life example.\n- Solve the problem step by step and give final answer.\n\n\nOutput format:\nAnswer the question clearly in simple words with one example.\n\nExplain:\nwhat is the probability of getting two tails when a coin is tossed twice?\n\n\nSolution:\nThe probability of getting two tails when a coin is tossed twice is calculated by considering all possible outcomes and the number of favorable outcomes. A coin has two sides, heads (H) and tails (T). When tossed twice, there are four possible outcomes: HH, HT, TH, TT. Only one of these outcomes is two tails (TT). Therefore, the probability is 1 out of 4, or 1/4.\n\n\nExample:\nImagine you have a fair coin and you toss it twice. There\'s a 25% chance that both tosses will re
# ...

# %%
ask_ai("calculate mean as n=12 and sum of X =500?")
# Out:
# '\nYou are a Statistics teacher.\n\nInstruction:\n- Understand the type of question first.\n- If it is a definition question → explain simply.\n- If it is a "when/which test" question → give conditions and rules.\n- Stay strictly on topic.\n- Always give a real-life example.\n- Solve the problem step by step and give final answer.\n\n\nOutput format:\nAnswer the question clearly in simple words with one example.\n\nExplain:\ncalculate mean as n=12 and sum of X =500?\n\nSolution:\nThe mean, often referred to as the average, is calculated by dividing the sum of all values by the number of values. In this case, we have a sum of X (which represents the sum of all values) equal to 500, and the number of values (n) is 12.\n\nTo calculate the mean, we use the formula:\n\nMean = Sum of all values / Number of values\n\nSo, plugging in the given values:\n\nMean = 500 / 12\n\nMean ≈ 41.67\n\nTherefore, the mean of the given data set is approximately 41.6'
